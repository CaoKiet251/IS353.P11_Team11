# %% [markdown]
# #Install

# %%
# !pip install pandas

# %% [markdown]
# #Connection Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Read data

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
train_truth = pd.read_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/raw_data/train_truth.csv')
train_truth.info()
train_truth
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157943 entries, 0 to 157942
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   enroll_id  157943 non-null  int64
#  1   truth      157943 non-null  int64
# dtypes: int64(2)
# memory usage: 2.4 MB
#         enroll_id  truth
# 0             772      1
# 1             773      1
# 2             774      1
# 3             776      0
# 4             777      1
# ...           ...    ...
# 157938     466774      1
# 157939     466776      1
# 157940     466781      1
# 157941     466782      1
# 157942     466786      0
#
# [157943 rows x 2 columns]

# %%
train_log = pd.read_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/data_sau_xử_lý/train_log_processed.csv')
train_log.info()
train_log.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29165540 entries, 0 to 29165539
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   enroll_id   int64
#  2   username    int64
#  3   course_id   object
#  4   session_id  object
#  5   action      object
#  6   object      object
#  7   time        object
# dtypes: int64(3), object(5)
# memory usage: 1.7+ GB
#    Unnamed: 0  enroll_id  username                              course_id  \
# 0           0        772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 1           1        772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 2           2        773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 3           3        773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 4           4        773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
#
#                          session_id       action  \
# 0  d8a9b787fa69063c34c73b9c29190b1c  click_about
# ...

# %%
user_info = pd.read_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/data_sau_xử_lý/user_info_processed.csv')
user_info.info()
user_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9627148 entries, 0 to 9627147
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   user_id     int64
#  2   gender      int64
#  3   education   object
#  4   birth       float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 367.2+ MB
#          Unnamed: 0   user_id  gender   education   birth
# 0             72298    280849       1  Bachelor's  1997.0
# 1            202358   6776280       1        High  1997.0
# 2            208379   6775883       1  Bachelor's  1997.0
# 3            240417  10125494       1    Master's  1997.0
# 4            278448   3039301       0        High  1997.0
# ...             ...       ...     ...         ...     ...
# 9627143     9548961     79056       0   Doctorate  2014.0
# 9627144     9579048    101553       1   Associate  1991.0
# 9627145     9585223    434554       0  Bachelor's  1989.0
# ...

# %%
course_info = pd.read_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/data_sau_xử_lý/course_info_processed.csv')
course_info.info()
course_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6410 entries, 0 to 6409
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   6410 non-null   int64
#  1   id           6410 non-null   object
#  2   course_id    6410 non-null   object
#  3   course_type  6410 non-null   int64
#  4   category     6410 non-null   object
#  5   start_date   6410 non-null   object
#  6   end_date     6410 non-null   object
#  7   duration     6410 non-null   int64
#  8   start_tsp    6410 non-null   int64
#  9   end_tsp      6410 non-null   int64
# dtypes: int64(5), object(5)
# memory usage: 500.9+ KB
#       Unnamed: 0     id                                    course_id  \
# 0             17    577                  TsinghuaX/70150023X/2015_T1
# 1             38   5735                 course-v1:NJU+010101+2016_T1
# 2             41  11612               course-v1:DYU+dyuglbbx+2017_T2
# ...

# %%
#Số mẫu cần dự đoán trong train_truth
print(int(train_truth['enroll_id'].count()))
# Out:
# 157943

# %% [markdown]
# #Course features

# %% [markdown]
# ##Số lượng học viên đã tham gia vào khóa học

# %%
#Xác định lần cuối cùng truy cập khóa học
latest_train_log = train_log.groupby('enroll_id')['time'].max().reset_index()
latest_train_log.columns = ['enroll_id','latest_date']
course_features_train = pd.merge(latest_train_log, train_log[['enroll_id','course_id']].drop_duplicates(), on='enroll_id', how='left')
course_features_train = pd.merge(course_features_train, train_truth, on='enroll_id', how='left')
course_features_train
# Out:
#         enroll_id latest_date                              course_id  truth
# 0             772  2015-09-27  course-v1:TsinghuaX+70800232X+2015_T2      1
# 1             773  2015-10-19  course-v1:TsinghuaX+70800232X+2015_T2      1
# 2             774  2015-10-29  course-v1:TsinghuaX+70800232X+2015_T2      1
# 3             776  2015-10-25  course-v1:TsinghuaX+70800232X+2015_T2      0
# 4             777  2015-10-05  course-v1:TsinghuaX+70800232X+2015_T2      1
# ...           ...         ...                                    ...    ...
# 157938     466774  2016-03-27  course-v1:TsinghuaX+AP000001X+2016_T1      1
# 157939     466776  2016-03-20  course-v1:TsinghuaX+AP000001X+2016_T1      1
# 157940     466781  2016-04-02  course-v1:TsinghuaX+AP000001X+2016_T1      1
# 157941     466782  2016-03-06  course-v1:TsinghuaX+AP000001X+2016_T1      1
# 157942     466786  2016-04-01  course-v1:TsinghuaX+AP000001X+2016_T1      0
#
# [157943 rows x 4 columns]

# %%
# Sort theo ngày tăng dần
course_features_train = course_features_train.sort_values(by=['course_id', 'latest_date'])
# Tạo cột đếm số lượng học viên trước thời điểm latest_date của mỗi enroll_id
course_features_train['previous_enroll_num'] = course_features_train.groupby('course_id').cumcount()
course_features_train
# Out:
#         enroll_id latest_date                  course_id  truth  \
# 33047       96783  2015-09-08      CAU/08112500x/2015_T2      1
# 33096       96906  2015-09-08      CAU/08112500x/2015_T2      1
# 33153       97041  2015-09-08      CAU/08112500x/2015_T2      1
# 33220       97202  2015-09-08      CAU/08112500x/2015_T2      1
# 33259       97313  2015-09-08      CAU/08112500x/2015_T2      1
# ...           ...         ...                        ...    ...
# 145102     432341  2016-03-28  course-v1:ustcX+USTC001+_      0
# 145107     432346  2016-03-28  course-v1:ustcX+USTC001+_      1
# 145155     432449  2016-03-28  course-v1:ustcX+USTC001+_      0
# 145163     432468  2016-03-28  course-v1:ustcX+USTC001+_      1
# 144834     431792  2016-03-29  course-v1:ustcX+USTC001+_      0
#
#         previous_enroll_num
# 33047                     0
# 33096                     1
# 33153                     2
# 33220                     3
# 33259                     4
# ...

# %% [markdown]
# ##Số lượng học viên đã bỏ học trước ngày đăng ký

# %%
course_features_train = course_features_train.sort_values(by=['course_id', 'latest_date'])

# Tạo cột đếm số lượng học viên bỏ học trước thời điểm latest_date của mỗi enroll_id
# Sử dụng hàm cumcount() để đếm số lượng truth = 1 trước latest_date
course_features_train['previous_dropout_user_num'] = (
    course_features_train.groupby('course_id')['truth']
    .apply(lambda x: x.cumsum().shift(1).fillna(0))
    .reset_index(level=0, drop=True)
)
course_features_train['previous_dropout_user_num'] = course_features_train['previous_dropout_user_num'].astype(int)
course_features_train
# Out:
#         enroll_id latest_date                  course_id  truth  \
# 33047       96783  2015-09-08      CAU/08112500x/2015_T2      1
# 33096       96906  2015-09-08      CAU/08112500x/2015_T2      1
# 33153       97041  2015-09-08      CAU/08112500x/2015_T2      1
# 33220       97202  2015-09-08      CAU/08112500x/2015_T2      1
# 33259       97313  2015-09-08      CAU/08112500x/2015_T2      1
# ...           ...         ...                        ...    ...
# 145102     432341  2016-03-28  course-v1:ustcX+USTC001+_      0
# 145107     432346  2016-03-28  course-v1:ustcX+USTC001+_      1
# 145155     432449  2016-03-28  course-v1:ustcX+USTC001+_      0
# 145163     432468  2016-03-28  course-v1:ustcX+USTC001+_      1
# 144834     431792  2016-03-29  course-v1:ustcX+USTC001+_      0
#
#         previous_enroll_num  previous_dropout_user_num
# 33047                     0                          0
# 33096                     1                          1
# ...

# %%
# Kiểm tra
_ = course_features_train.loc[course_features_train['course_id'] == 'CAU/08112500x/2015_T2']
_
# Out:
#        enroll_id latest_date              course_id  truth  \
# 33047      96783  2015-09-08  CAU/08112500x/2015_T2      1
# 33096      96906  2015-09-08  CAU/08112500x/2015_T2      1
# 33153      97041  2015-09-08  CAU/08112500x/2015_T2      1
# 33220      97202  2015-09-08  CAU/08112500x/2015_T2      1
# 33259      97313  2015-09-08  CAU/08112500x/2015_T2      1
# ...          ...         ...                    ...    ...
# 33256      97309  2015-10-12  CAU/08112500x/2015_T2      0
# 33260      97316  2015-10-12  CAU/08112500x/2015_T2      0
# 33266      97326  2015-10-12  CAU/08112500x/2015_T2      1
# 33267      97329  2015-10-12  CAU/08112500x/2015_T2      0
# 33050      96789  2015-10-13  CAU/08112500x/2015_T2      1
#
#        previous_enroll_num  previous_dropout_user_num
# 33047                    0                          0
# 33096                    1                          1
# 33153                    2                          2
# ...

# %%
course_features_train = course_features_train.drop(columns=['latest_date', 'truth'])

# %%
course_features_train = pd.merge(course_features_train, course_info[['course_id', 'duration']], on='course_id', how='left')
course_features_train
# Out:
#         enroll_id                  course_id  previous_enroll_num  \
# 0           96783      CAU/08112500x/2015_T2                    0
# 1           96906      CAU/08112500x/2015_T2                    1
# 2           97041      CAU/08112500x/2015_T2                    2
# 3           97202      CAU/08112500x/2015_T2                    3
# 4           97313      CAU/08112500x/2015_T2                    4
# ...           ...                        ...                  ...
# 157938     432341  course-v1:ustcX+USTC001+_                  479
# 157939     432346  course-v1:ustcX+USTC001+_                  480
# 157940     432449  course-v1:ustcX+USTC001+_                  481
# 157941     432468  course-v1:ustcX+USTC001+_                  482
# 157942     431792  course-v1:ustcX+USTC001+_                  483
#
#         previous_dropout_user_num  duration
# 0                               0       297
# 1                               1       297
# ...

# %%
course_features_train.count()
# Out:
# enroll_id                    157943
# course_id                    157943
# previous_enroll_num          157943
# previous_dropout_user_num    157943
# duration                     157943
# dtype: int64

# %%
course_features_train.to_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/data_sau_xử_lý/trích_xuất_dữ_liệu/course_features_train.csv')

# %% [markdown]
# #User features

# %%
user_features_train = train_log[['enroll_id', 'username']].drop_duplicates()
user_features_train = pd.merge(user_features_train, train_truth, on='enroll_id', how='inner')
user_features_train
# Out:
#         enroll_id  username  truth
# 0             772      5981      1
# 1             773   1544995      1
# 2             774   1072798      1
# 3             776    561867      0
# 4             777   1368125      1
# ...           ...       ...    ...
# 157938     466774   2588048      1
# 157939     466776   2736225      1
# 157940     466781   2830711      1
# 157941     466782   2680742      1
# 157942     466786   2659552      0
#
# [157943 rows x 3 columns]

# %% [markdown]
# Vậy các user trong file train đều có thông tin trong user_info

# %% [markdown]
# ## Encode cột education

# %% [markdown]
# Encode 'education' theo thứ tự từ 0 - 6: ["Bachelor's", "Master's", 'High', 'Associate', 'Doctorate', 'Middle', 'Primary']

# %%
education_map = {
    "Bachelor's": 0,
    "Master's": 1,
    "High": 2,
    "Associate": 3,
    "Doctorate": 4,
    "Middle": 5,
    "Primary": 6
}
user_features_train = pd.merge(user_features_train, user_info, left_on='username', right_on='user_id', how='left')
user_features_train['education'] = user_features_train['education'].map(education_map)
user_features_train
# Out:
#         enroll_id  username  truth  Unnamed: 0  user_id  gender  education  \
# 0             772      5981      1      613695     5981       0          1
# 1             773   1544995      1     1878114  1544995       1          0
# 2             774   1072798      1     1053475  1072798       0          0
# 3             776    561867      0     7184420   561867       1          3
# 4             777   1368125      1     5885315  1368125       0          0
# ...           ...       ...    ...         ...      ...     ...        ...
# 157938     466774   2588048      1     6084549  2588048       0          5
# 157939     466776   2736225      1     4014797  2736225       0          1
# 157940     466781   2830711      1      314440  2830711       1          1
# 157941     466782   2680742      1      452751  2680742       1          2
# 157942     466786   2659552      0     4796926  2659552       1          0
#
#          birth
# 0       1989.0
# 1       1997.0
# 2       1997.0
# ...

# %%
# Bỏ các cột không cần thiết
user_features_train = user_features_train.drop(['username', 'Unnamed: 0'], axis=1)
user_features_train
# Out:
#         enroll_id  truth  user_id  gender  education   birth
# 0             772      1     5981       0          1  1989.0
# 1             773      1  1544995       1          0  1997.0
# 2             774      1  1072798       0          0  1997.0
# 3             776      0   561867       1          3  1981.0
# 4             777      1  1368125       0          0  1997.0
# ...           ...    ...      ...     ...        ...     ...
# 157938     466774      1  2588048       0          5  1999.0
# 157939     466776      1  2736225       0          1  1997.0
# 157940     466781      1  2830711       1          1  1997.0
# 157941     466782      1  2680742       1          2  1997.0
# 157942     466786      0  2659552       1          0  1997.0
#
# [157943 rows x 6 columns]

# %% [markdown]
# ## Tính tuổi

# %%
user_features_train = pd.merge(user_features_train, latest_train_log, on='enroll_id', how='inner')

def tinh_tuoi(row):
    row = pd.to_datetime(row)
    tuoi = row.dt.year
    return tuoi

user_features_train['age'] = tinh_tuoi(user_features_train['latest_date']) - user_features_train['birth']
user_features_train = user_features_train.drop('birth', axis=1)
user_features_train
# Out:
#         enroll_id  truth  user_id  gender  education latest_date   age
# 0             772      1     5981       0          1  2015-09-27  26.0
# 1             773      1  1544995       1          0  2015-10-19  18.0
# 2             774      1  1072798       0          0  2015-10-29  18.0
# 3             776      0   561867       1          3  2015-10-25  34.0
# 4             777      1  1368125       0          0  2015-10-05  18.0
# ...           ...    ...      ...     ...        ...         ...   ...
# 157938     466774      1  2588048       0          5  2016-03-27  17.0
# 157939     466776      1  2736225       0          1  2016-03-20  19.0
# 157940     466781      1  2830711       1          1  2016-04-02  19.0
# 157941     466782      1  2680742       1          2  2016-03-06  19.0
# 157942     466786      0  2659552       1          0  2016-04-01  19.0
#
# [157943 rows x 7 columns]

# %% [markdown]
# ## Tính tổng số lượng tất cả các khoá học đã bỏ trước đó

# %%
user_features_train = user_features_train.sort_values('latest_date', ascending=True)
user_features_train
# Out:
#         enroll_id  truth  user_id  gender  education latest_date   age
# 84565      242433      1    82026       1          0  2015-06-04  27.0
# 36291      106389      1    25817       0          0  2015-06-04  26.0
# 137412     410336      0    11191       1          0  2015-06-04  25.0
# 137143     409592      1    98849       1          0  2015-06-04  18.0
# 84495      242236      1   576550       0          4  2015-06-04  18.0
# ...           ...    ...      ...     ...        ...         ...   ...
# 98503      287325      0   217155       1          1  2017-06-04  29.0
# 98473      287254      0   346756       0          0  2017-06-04  53.0
# 98475      287256      0  1071211       1          0  2017-06-05  24.0
# 98791      288111      0   100340       0          2  2017-06-05  23.0
# 98676      287745      0  6679328       0          0  2017-06-05  20.0
#
# [157943 rows x 7 columns]

# %%
# Tinh tong so khoa hoc da bo
user_features_train['dropout_count'] = user_features_train.groupby('user_id')['truth'].cumsum()
user_features_train
# Out:
#         enroll_id  truth  user_id  gender  education latest_date   age  \
# 84565      242433      1    82026       1          0  2015-06-04  27.0
# 36291      106389      1    25817       0          0  2015-06-04  26.0
# 137412     410336      0    11191       1          0  2015-06-04  25.0
# 137143     409592      1    98849       1          0  2015-06-04  18.0
# 84495      242236      1   576550       0          4  2015-06-04  18.0
# ...           ...    ...      ...     ...        ...         ...   ...
# 98503      287325      0   217155       1          1  2017-06-04  29.0
# 98473      287254      0   346756       0          0  2017-06-04  53.0
# 98475      287256      0  1071211       1          0  2017-06-05  24.0
# 98791      288111      0   100340       0          2  2017-06-05  23.0
# 98676      287745      0  6679328       0          0  2017-06-05  20.0
#
#         dropout_count
# 84565               1
# 36291               1
# 137412              0
# ...

# %%
# Tinh tong so khoa hoc da bo trc do
# sử dụng where các giá trị có truth = 0 thì giữ nguyên, ngược lại trừ đi 1
user_features_train['prev_dropout_num'] = user_features_train['dropout_count'].where( user_features_train['truth'] == 0, user_features_train['dropout_count'] - 1)
user_features_train = user_features_train.drop('dropout_count',axis=1)

user_features_train
# Out:
#         enroll_id  truth  user_id  gender  education latest_date   age  \
# 84565      242433      1    82026       1          0  2015-06-04  27.0
# 36291      106389      1    25817       0          0  2015-06-04  26.0
# 137412     410336      0    11191       1          0  2015-06-04  25.0
# 137143     409592      1    98849       1          0  2015-06-04  18.0
# 84495      242236      1   576550       0          4  2015-06-04  18.0
# ...           ...    ...      ...     ...        ...         ...   ...
# 98503      287325      0   217155       1          1  2017-06-04  29.0
# 98473      287254      0   346756       0          0  2017-06-04  53.0
# 98475      287256      0  1071211       1          0  2017-06-05  24.0
# 98791      288111      0   100340       0          2  2017-06-05  23.0
# 98676      287745      0  6679328       0          0  2017-06-05  20.0
#
#         prev_dropout_num
# 84565                  0
# 36291                  0
# 137412                 0
# ...

# %%
_ = user_features_train.loc[user_features_train['user_id'] == 82026	]
_
# Out:
#        enroll_id  truth  user_id  gender  education latest_date   age  \
# 84565     242433      1    82026       1          0  2015-06-04  27.0
# 40598     119505      1    82026       1          0  2015-10-23  27.0
#
#        prev_dropout_num
# 84565                 0
# 40598                 1

# %%
user_features_train = user_features_train.drop(['truth','latest_date'],axis=1)
user_features_train.to_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/data_sau_xử_lý/trích_xuất_dữ_liệu/user_features_train.csv')

# %% [markdown]
# #log features

# %% [markdown]
# ##Tổng số session

# %%
# Đếm số lượng session_id
session_num_train = train_log.groupby('enroll_id')['session_id'].nunique().reset_index()
session_num_train.columns = ['enroll_id', 'session_num']
session_num_train
# Out:
#         enroll_id  session_num
# 0             772            1
# 1             773            1
# 2             774            3
# 3             776            1
# 4             777            1
# ...           ...          ...
# 157938     466774            2
# 157939     466776            1
# 157940     466781            1
# 157941     466782            2
# 157942     466786            3
#
# [157943 rows x 2 columns]

# %% [markdown]
# ##Tổng số lần tương tác với video

# %%
#Lọc ra các action có từ 'video'
video_actions_train = train_log[train_log['action'].str.contains('video')]
# Lấy ra số lần tương tác video theo từng enroll_id
video_num_train = video_actions_train.groupby('enroll_id').size().reset_index(name='video_num')

# Merge lại với enroll_id của train_log để lấy ra đc cái user không có action video và set giá trị bằng 0
enroll_ids_train = train_log[['enroll_id']].drop_duplicates()
video_num_train = pd.merge(enroll_ids_train, video_num_train, on='enroll_id', how='left').fillna(0)

video_num_train['video_num'] = video_num_train['video_num'].astype(int)
print(video_num_train)
# Out:
#         enroll_id  video_num
# 0             772          0
# 1             773         14
# 2             774         42
# 3             776          9
# 4             777          0
# ...           ...        ...
# 157938     466774          4
# 157939     466776         10
# 157940     466781          0
# 157941     466782          3
# 157942     466786          4
#
# [157943 rows x 2 columns]

# %% [markdown]
# ##Tổng số lần tương tác với giáo trình

# %%
#Lọc ra các action có từ 'courseware'
courseware_actions_train = train_log[train_log['action'].str.contains('courseware')]
# Lấy ra số lượng coi courseware theo từng enroll_id
courseware_num_train = courseware_actions_train.groupby('enroll_id').size().reset_index(name='courseware_num')

# Merge lại với enroll_id của train_log để lấy ra đc cái user không có action courseware và set giá trị bằng 0
courseware_num_train = pd.merge(enroll_ids_train, courseware_num_train, on='enroll_id', how='left').fillna(0)
courseware_num_train['courseware_num'] = courseware_num_train['courseware_num'].astype(int)

print(courseware_num_train)
# Out:
#         enroll_id  courseware_num
# 0             772               0
# 1             773               3
# 2             774              26
# 3             776               6
# 4             777               2
# ...           ...             ...
# 157938     466774               6
# 157939     466776               5
# 157940     466781               0
# 157941     466782               8
# 157942     466786              24
#
# [157943 rows x 2 columns]

# %%
log_features_train = pd.merge(session_num_train, video_num_train, on='enroll_id', how='inner')
log_features_train = pd.merge(log_features_train, courseware_num_train, on='enroll_id', how='inner')
print(log_features_train)
# Out:
#         enroll_id  session_num  video_num  courseware_num
# 0             772            1          0               0
# 1             773            1         14               3
# 2             774            3         42              26
# 3             776            1          9               6
# 4             777            1          0               2
# ...           ...          ...        ...             ...
# 157938     466774            2          4               6
# 157939     466776            1         10               5
# 157940     466781            1          0               0
# 157941     466782            2          3               8
# 157942     466786            3          4              24
#
# [157943 rows x 4 columns]

# %%
log_features_train.to_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/data_sau_xử_lý/trích_xuất_dữ_liệu/log_features_train.csv')

# %% [markdown]
# # Concate feature

# %%
print(len(user_features_train))
print(len(course_features_train))
print(len(log_features_train))
# Out:
# 157943
# 157943
# 157943

# %%
train_features = pd.merge(user_features_train, course_features_train, on='enroll_id', how='inner')
train_features = pd.merge(train_features, log_features_train, on='enroll_id', how='inner')
train_features = pd.merge(train_features, train_truth, on='enroll_id', how='inner')
train_features = train_features.drop('course_id', axis=1)
train_features = train_features.drop(['user_id','gender'], axis=1)
train_features
# Out:
#         enroll_id  gender  education   age  prev_dropout_num  \
# 0          242433       1          0  27.0                 0
# 1          106389       0          0  26.0                 0
# 2          410336       1          0  25.0                 0
# 3          409592       1          0  18.0                 0
# 4          242236       0          4  18.0                 0
# ...           ...     ...        ...   ...               ...
# 157938     287325       1          1  29.0                 2
# 157939     287254       0          0  53.0                15
# 157940     287256       1          0  24.0                 0
# 157941     288111       0          2  23.0                 0
# 157942     287745       0          0  20.0                 1
#
#         previous_enroll_num  previous_dropout_user_num  duration  session_num  \
# 0                        12                          8       128            1
# ...

# %%
train_features.to_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/data_sau_xử_lý/trích_xuất_dữ_liệu/train_set.csv')
