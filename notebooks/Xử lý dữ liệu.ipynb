# %% [markdown]
# #Install

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# #Connection Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Read Data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##user_info

# %%
user_info = pd.read_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/raw_data/user_info.csv')
user_info.info()
user_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9627148 entries, 0 to 9627147
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   user_id    int64
#  1   gender     object
#  2   education  object
#  3   birth      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 293.8+ MB
#           user_id gender   education   birth
# 0             631   male        High  1997.0
# 1            2631   male  Bachelor's  1990.0
# 2            4231   male   Associate  1991.0
# 3            6031   male  Bachelor's  1988.0
# 4            7831    NaN         NaN     NaN
# ...           ...    ...         ...     ...
# 9627143  10435606    NaN         NaN     NaN
# 9627144  10437206    NaN         NaN     NaN
# 9627145  10438806    NaN         NaN     NaN
# 9627146  10440406    NaN         NaN     NaN
# 9627147  10442006    NaN         NaN     NaN
#
# [9627148 rows x 4 columns]

# %% [markdown]
# ##course_info

# %%
course_info = pd.read_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/raw_data/course_info.csv')
course_info.info()
course_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6410 entries, 0 to 6409
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           6410 non-null   object
#  1   course_id    6410 non-null   object
#  2   start        6410 non-null   object
#  3   end          5877 non-null   object
#  4   course_type  6410 non-null   int64
#  5   category     1454 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 300.6+ KB
#          id                                course_id                start  \
# 0      6561    course-v1:CPVS+CPVS-HDLSC001+20160901  2016-11-16 08:00:00
# 1      5557             course-v1:SCUT+144282+201709  2016-09-01 00:00:00
# 2      9433                     course-v1:ZK+06093+J  2018-01-01 08:00:00
# 3      8320              course-v1:nuist+001+2016-T1  2017-03-01 18:30:00
# 4       231               FUDAN/CFD004/2014.9-2015.1  2014-09-10 08:00:00
# ...     ...                                      ...                  ...
# 6405  10493        course-v1:NBUX+lzu_MH001x+2017_T1  2017-04-10 00:00:00
# 6406  11058          course-v1:Train+Train12+2017_T1  2017-05-01 08:00:00
# 6407   4184         course-v1:nttec+10610204+2015_T2  2015-12-07 00:00:00
# 6408   8333  course-v1:TsinghuaX+60610231+2016_T2_SP  2016-08-25 08:00:00
# 6409   7848      course-v1:ncepubd+00510663X+2016_T2  2016-10-12 08:00:00
#
#                       end  course_type    category
# 0     2016-12-31 23:30:00            0         NaN
# 1     2017-02-28 00:00:00            0         NaN
# 2     2020-01-01 00:00:00            0         NaN
# 3     2017-07-01 23:30:00            0         NaN
# 4     2015-09-10 00:00:00            0         NaN
# ...                   ...          ...         ...
# 6405  2017-05-21 23:59:00            0         NaN
# 6406  2017-05-31 00:00:00            0         NaN
# 6407  2016-12-07 00:00:00            0         NaN
# 6408                  NaN            1  philosophy
# 6409  2016-12-30 08:00:00            0         NaN
#
# [6410 rows x 6 columns]

# %% [markdown]
# ##train_log

# %%
train_log = pd.read_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/raw_data/train_log.csv')
train_log.info()
train_log
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29165540 entries, 0 to 29165539
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   enroll_id   int64
#  1   username    int64
#  2   course_id   object
#  3   session_id  object
#  4   action      object
#  5   object      object
#  6   time        object
# dtypes: int64(2), object(5)
# memory usage: 1.5+ GB
#           enroll_id  username                              course_id  \
# 0               772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 1               772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 2               773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 3               773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 4               773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# ...             ...       ...                                    ...
# 29165535     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165536     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165537     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165538     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165539     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
#
#                                 session_id            action  \
# 0         d8a9b787fa69063c34c73b9c29190b1c       click_about
# 1         d8a9b787fa69063c34c73b9c29190b1c        click_info
# 2         2f02b86eb3ea2cbf0be11385a8dc62e5       pause_video
# 3         2f02b86eb3ea2cbf0be11385a8dc62e5        load_video
# 4         2f02b86eb3ea2cbf0be11385a8dc62e5        play_video
# ...                                    ...               ...
# 29165535  dff9476c7f05f26a69a06506fe471668  click_courseware
# 29165536  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165537  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165538  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165539  d94bf93252b8936bef09f6e46c24d50d       click_about
#
#                                     object                 time
# 0                                      NaN  2015-09-27T15:42:59
# 1                                      NaN  2015-09-27T15:43:12
# 2         3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:37:42
# 3         3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:33:27
# 4         3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:33:30
# ...                                    ...                  ...
# 29165535                               NaN  2016-04-01T21:04:38
# 29165536  556186425e7448e189918bafcb2ff30b  2016-04-01T21:04:38
# 29165537  1757e4fd85994ba9a2350780f96da89e  2016-04-01T21:04:38
# 29165538  686d5efcd27845379b4b90e41ece181d  2016-04-01T21:04:38
# 29165539                               NaN  2016-03-02T20:21:55
#
# [29165540 rows x 7 columns]

# %% [markdown]
# ##test_log

# %%
test_log = pd.read_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/raw_data/test_log.csv')
test_log.info()
test_log
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12944862 entries, 0 to 12944861
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   enroll_id   int64
#  1   username    int64
#  2   course_id   object
#  3   session_id  object
#  4   action      object
#  5   object      object
#  6   time        object
# dtypes: int64(2), object(5)
# memory usage: 691.3+ MB
#           enroll_id  username                              course_id  \
# 0               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 1               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 2               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 3               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 4               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# ...             ...       ...                                    ...
# 12944857     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944858     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944859     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944860     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944861     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
#
#                                 session_id                   action  \
# 0         5f421f644193c2d48c84df42aaf7e48b               load_video
# 1         5f421f644193c2d48c84df42aaf7e48b               load_video
# 2         5f421f644193c2d48c84df42aaf7e48b               play_video
# 3         5f421f644193c2d48c84df42aaf7e48b              pause_video
# 4         5f421f644193c2d48c84df42aaf7e48b               stop_video
# ...                                    ...                      ...
# 12944857  b12bc83e13cd943cf61bf78f09c72158  problem_check_incorrect
# 12944858  b12bc83e13cd943cf61bf78f09c72158  problem_check_incorrect
# 12944859  b12bc83e13cd943cf61bf78f09c72158    problem_check_correct
# 12944860  7eca0904ae14dc8af809c0362632dd8e         click_courseware
# 12944861  b12bc83e13cd943cf61bf78f09c72158              problem_get
#
#                                     object                 time
# 0         3dac5590435e43b3a65a9ae7426c16db  2015-10-15T22:14:11
# 1         3169d758ee2d4262b07f0113df743c42  2015-10-15T22:43:35
# 2         3169d758ee2d4262b07f0113df743c42  2015-10-15T22:43:40
# 3         3169d758ee2d4262b07f0113df743c42  2015-10-15T22:55:38
# 4         3169d758ee2d4262b07f0113df743c42  2015-10-15T22:55:38
# ...                                    ...                  ...
# 12944857  31aa97345c46473badab334379f995d8  2016-03-19T21:37:15
# 12944858  31aa97345c46473badab334379f995d8  2016-03-19T21:37:22
# 12944859  31aa97345c46473badab334379f995d8  2016-03-19T21:37:37
# 12944860                               NaN  2016-03-19T19:24:44
# 12944861  a028651adbdc4bc0b53191117f874fbc  2016-03-19T21:38:34
#
# [12944862 rows x 7 columns]

# %% [markdown]
# #course_info

# %% [markdown]
# ##1. Các dòng dữ liệu có cột 'start' không nằm trong khoảng 01/01/2015 - 31/08/2017

# %% [markdown]
# ###1.1 Chuyển đổi dữ liệu ngày sang dạng date

# %%
scourse_date = course_info.copy()
course_date['start_date'] = pd.to_datetime(course_date['start']).dt.normalize()
course_date['end_date'] = pd.to_datetime(course_date['end']).dt.normalize()
course_date.drop(columns=['start', 'end'], inplace=True)

course_date.info()
course_date
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6410 entries, 0 to 6409
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           6410 non-null   object
#  1   course_id    6410 non-null   object
#  2   course_type  6410 non-null   int64
#  3   category     1454 non-null   object
#  4   start_date   6410 non-null   datetime64[ns]
#  5   end_date     5877 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 300.6+ KB
#          id                                course_id  course_type    category  \
# 0      6561    course-v1:CPVS+CPVS-HDLSC001+20160901            0         NaN
# 1      5557             course-v1:SCUT+144282+201709            0         NaN
# 2      9433                     course-v1:ZK+06093+J            0         NaN
# 3      8320              course-v1:nuist+001+2016-T1            0         NaN
# 4       231               FUDAN/CFD004/2014.9-2015.1            0         NaN
# ...     ...                                      ...          ...         ...
# 6405  10493        course-v1:NBUX+lzu_MH001x+2017_T1            0         NaN
# 6406  11058          course-v1:Train+Train12+2017_T1            0         NaN
# 6407   4184         course-v1:nttec+10610204+2015_T2            0         NaN
# 6408   8333  course-v1:TsinghuaX+60610231+2016_T2_SP            1  philosophy
# 6409   7848      course-v1:ncepubd+00510663X+2016_T2            0         NaN
#
#      start_date   end_date
# 0    2016-11-16 2016-12-31
# 1    2016-09-01 2017-02-28
# 2    2018-01-01 2020-01-01
# 3    2017-03-01 2017-07-01
# 4    2014-09-10 2015-09-10
# ...         ...        ...
# 6405 2017-04-10 2017-05-21
# 6406 2017-05-01 2017-05-31
# 6407 2015-12-07 2016-12-07
# 6408 2016-08-25        NaT
# 6409 2016-10-12 2016-12-30
#
# [6410 rows x 6 columns]

# %% [markdown]
# ###1.2 Các khóa học không có 'start_date' không thỏa mãn, chuyển về 01/01/2015

# %%
course_date['start_date'] = np.where(
  (course_date['start_date'] < pd.to_datetime('2015-01-01')) |
  (course_date['start_date'] > pd.to_datetime('2017-08-31')) ,
  pd.to_datetime('2015-01-01'),
  course_date['start_date']
)
course_date['start_date'] = pd.to_datetime(course_date['start_date'])

course_date.info()
course_date
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6410 entries, 0 to 6409
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           6410 non-null   object
#  1   course_id    6410 non-null   object
#  2   course_type  6410 non-null   int64
#  3   category     1454 non-null   object
#  4   start_date   6410 non-null   datetime64[ns]
#  5   end_date     5877 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 300.6+ KB
#          id                                course_id  course_type    category  \
# 0      6561    course-v1:CPVS+CPVS-HDLSC001+20160901            0         NaN
# 1      5557             course-v1:SCUT+144282+201709            0         NaN
# 2      9433                     course-v1:ZK+06093+J            0         NaN
# 3      8320              course-v1:nuist+001+2016-T1            0         NaN
# 4       231               FUDAN/CFD004/2014.9-2015.1            0         NaN
# ...     ...                                      ...          ...         ...
# 6405  10493        course-v1:NBUX+lzu_MH001x+2017_T1            0         NaN
# 6406  11058          course-v1:Train+Train12+2017_T1            0         NaN
# 6407   4184         course-v1:nttec+10610204+2015_T2            0         NaN
# 6408   8333  course-v1:TsinghuaX+60610231+2016_T2_SP            1  philosophy
# 6409   7848      course-v1:ncepubd+00510663X+2016_T2            0         NaN
#
#      start_date   end_date
# 0    2016-11-16 2016-12-31
# 1    2016-09-01 2017-02-28
# 2    2015-01-01 2020-01-01
# 3    2017-03-01 2017-07-01
# 4    2015-01-01 2015-09-10
# ...         ...        ...
# 6405 2017-04-10 2017-05-21
# 6406 2017-05-01 2017-05-31
# 6407 2015-12-07 2016-12-07
# 6408 2016-08-25        NaT
# 6409 2016-10-12 2016-12-30
#
# [6410 rows x 6 columns]

# %% [markdown]
# ##2. Các dòng null, year > 2018, < 'start_date' trong cột 'end_date'

# %% [markdown]
# ###2.1 Các dòng 'end_date' không hợp lệ

# %%
invalid_rows = pd.concat([course_date[pd.DatetimeIndex(course_date['end_date']).year > 2018],
                          course_date[course_date['end_date'].isnull()],
                          course_date[course_date['end_date'] < course_date['start_date']]
                        ])
invalid_rows.info()
invalid_rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 903 entries, 2 to 6180
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           903 non-null    object
#  1   course_id    903 non-null    object
#  2   course_type  903 non-null    int64
#  3   category     471 non-null    object
#  4   start_date   903 non-null    datetime64[ns]
#  5   end_date     370 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 49.4+ KB
#          id                                    course_id  course_type  \
# 2      9433                         course-v1:ZK+06093+J            0
# 14    10988                  course-v1:SDJTU+lyh+2017_T2            0
# 46     9378                         course-v1:ZK+00316+J            0
# 48    11495           course-v1:CQU+TSJYSSG00031+2017_T1            0
# 68    11384            course-v1:CQU+TSJYHG00062+2017_T1            0
# ...     ...                                          ...          ...
# 5741     69                          PekingX/01718330X/_            0
# 5862   8109  course-v1:UC_BerkeleyX+CS169_1x_1+2016_2017            0
# 6096   5882             course-v1:rongxin+cq01001+201603            0
# 6144    253                       FUDAN/FUDAN004/2014_T2            0
# 6180     82                        TsinghuaX/70167012X/_            0
#
#       category start_date   end_date
# 2          NaN 2015-01-01 2020-01-01
# 14         NaN 2017-04-01 2030-08-31
# 46         NaN 2015-01-01 2020-01-01
# 48         NaN 2017-05-01 2020-05-01
# 68         NaN 2017-05-01 2020-05-01
# ...        ...        ...        ...
# 5741  computer 2015-01-01 2014-01-23
# 5862       NaN 2015-01-01 2014-11-27
# 6096       NaN 2017-01-01 2016-12-31
# 6144       NaN 2015-01-01 2014-05-14
# 6180       art 2015-01-01 2014-07-21
#
# [903 rows x 6 columns]

# %% [markdown]
# ###2.2 Tính khoảng thời gian khóa học 'duration' với các dòng 'end_date' hợp lệ

# %%
valid_rows = course_date.loc[~course_date['id'].isin(invalid_rows['id'])]
valid_rows.info()
valid_rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5507 entries, 0 to 6409
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           5507 non-null   object
#  1   course_id    5507 non-null   object
#  2   course_type  5507 non-null   int64
#  3   category     983 non-null    object
#  4   start_date   5507 non-null   datetime64[ns]
#  5   end_date     5507 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 301.2+ KB
#          id                              course_id  course_type category  \
# 0      6561  course-v1:CPVS+CPVS-HDLSC001+20160901            0      NaN
# 1      5557           course-v1:SCUT+144282+201709            0      NaN
# 3      8320            course-v1:nuist+001+2016-T1            0      NaN
# 4       231             FUDAN/CFD004/2014.9-2015.1            0      NaN
# 5      7645           course-v1:ANUx+EBM05x+3T2017            0      NaN
# ...     ...                                    ...          ...      ...
# 6404   9709   course-v1:IITBombayX+CS101.2x+1T2017            0      NaN
# 6405  10493      course-v1:NBUX+lzu_MH001x+2017_T1            0      NaN
# 6406  11058        course-v1:Train+Train12+2017_T1            0      NaN
# 6407   4184       course-v1:nttec+10610204+2015_T2            0      NaN
# 6409   7848    course-v1:ncepubd+00510663X+2016_T2            0      NaN
#
#      start_date   end_date
# 0    2016-11-16 2016-12-31
# 1    2016-09-01 2017-02-28
# 3    2017-03-01 2017-07-01
# 4    2015-01-01 2015-09-10
# 5    2015-01-01 2018-09-17
# ...         ...        ...
# 6404 2017-02-21 2017-12-12
# 6405 2017-04-10 2017-05-21
# 6406 2017-05-01 2017-05-31
# 6407 2015-12-07 2016-12-07
# 6409 2016-10-12 2016-12-30
#
# [5507 rows x 6 columns]

# %%
valid_rows.loc[:, 'duration'] = (valid_rows['end_date'] - valid_rows['start_date']).dt.days
valid_rows.info()
valid_rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5507 entries, 0 to 6409
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           5507 non-null   object
#  1   course_id    5507 non-null   object
#  2   course_type  5507 non-null   int64
#  3   category     983 non-null    object
#  4   start_date   5507 non-null   datetime64[ns]
#  5   end_date     5507 non-null   datetime64[ns]
#  6   duration     5507 non-null   int64
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 344.2+ KB
#          id                              course_id  course_type category  \
# 0      6561  course-v1:CPVS+CPVS-HDLSC001+20160901            0      NaN
# 1      5557           course-v1:SCUT+144282+201709            0      NaN
# 3      8320            course-v1:nuist+001+2016-T1            0      NaN
# 4       231             FUDAN/CFD004/2014.9-2015.1            0      NaN
# 5      7645           course-v1:ANUx+EBM05x+3T2017            0      NaN
# ...     ...                                    ...          ...      ...
# 6404   9709   course-v1:IITBombayX+CS101.2x+1T2017            0      NaN
# 6405  10493      course-v1:NBUX+lzu_MH001x+2017_T1            0      NaN
# 6406  11058        course-v1:Train+Train12+2017_T1            0      NaN
# 6407   4184       course-v1:nttec+10610204+2015_T2            0      NaN
# 6409   7848    course-v1:ncepubd+00510663X+2016_T2            0      NaN
#
#      start_date   end_date  duration
# 0    2016-11-16 2016-12-31        45
# 1    2016-09-01 2017-02-28       180
# 3    2017-03-01 2017-07-01       122
# 4    2015-01-01 2015-09-10       252
# 5    2015-01-01 2018-09-17      1355
# ...         ...        ...       ...
# 6404 2017-02-21 2017-12-12       294
# 6405 2017-04-10 2017-05-21        41
# 6406 2017-05-01 2017-05-31        30
# 6407 2015-12-07 2016-12-07       366
# 6409 2016-10-12 2016-12-30        79
#
# [5507 rows x 7 columns]

# %% [markdown]
# ###2.3 Tính trung bình 'duration'

# %%
duration_mean = int(valid_rows['duration'].mean())
print(duration_mean)
# Out:
# 232

# %% [markdown]
# ###2.4 Set 'start_end' và 'duration' cho các dòng 'end_date' không hợp lệ

# %%
invalid_rows['end_date'] = invalid_rows['start_date'] + pd.to_timedelta(duration_mean, unit="days")
invalid_rows['duration'] = duration_mean
invalid_rows.info()
invalid_rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 903 entries, 2 to 6180
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           903 non-null    object
#  1   course_id    903 non-null    object
#  2   course_type  903 non-null    int64
#  3   category     471 non-null    object
#  4   start_date   903 non-null    datetime64[ns]
#  5   end_date     903 non-null    datetime64[ns]
#  6   duration     903 non-null    int64
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 56.4+ KB
#          id                                    course_id  course_type  \
# 2      9433                         course-v1:ZK+06093+J            0
# 14    10988                  course-v1:SDJTU+lyh+2017_T2            0
# 46     9378                         course-v1:ZK+00316+J            0
# 48    11495           course-v1:CQU+TSJYSSG00031+2017_T1            0
# 68    11384            course-v1:CQU+TSJYHG00062+2017_T1            0
# ...     ...                                          ...          ...
# 5741     69                          PekingX/01718330X/_            0
# 5862   8109  course-v1:UC_BerkeleyX+CS169_1x_1+2016_2017            0
# 6096   5882             course-v1:rongxin+cq01001+201603            0
# 6144    253                       FUDAN/FUDAN004/2014_T2            0
# 6180     82                        TsinghuaX/70167012X/_            0
#
#       category start_date   end_date  duration
# 2          NaN 2015-01-01 2015-08-21       232
# 14         NaN 2017-04-01 2017-11-19       232
# 46         NaN 2015-01-01 2015-08-21       232
# 48         NaN 2017-05-01 2017-12-19       232
# 68         NaN 2017-05-01 2017-12-19       232
# ...        ...        ...        ...       ...
# 5741  computer 2015-01-01 2015-08-21       232
# 5862       NaN 2015-01-01 2015-08-21       232
# 6096       NaN 2017-01-01 2017-08-21       232
# 6144       NaN 2015-01-01 2015-08-21       232
# 6180       art 2015-01-01 2015-08-21       232
#
# [903 rows x 7 columns]

# %% [markdown]
# ###2.5 Tổng hợp lại vào course_date

# %%
course_date = pd.concat([valid_rows, invalid_rows])
course_date.info()
course_date
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6410 entries, 0 to 6180
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           6410 non-null   object
#  1   course_id    6410 non-null   object
#  2   course_type  6410 non-null   int64
#  3   category     1454 non-null   object
#  4   start_date   6410 non-null   datetime64[ns]
#  5   end_date     6410 non-null   datetime64[ns]
#  6   duration     6410 non-null   int64
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 400.6+ KB
#         id                                    course_id  course_type  \
# 0     6561        course-v1:CPVS+CPVS-HDLSC001+20160901            0
# 1     5557                 course-v1:SCUT+144282+201709            0
# 3     8320                  course-v1:nuist+001+2016-T1            0
# 4      231                   FUDAN/CFD004/2014.9-2015.1            0
# 5     7645                 course-v1:ANUx+EBM05x+3T2017            0
# ...    ...                                          ...          ...
# 5741    69                          PekingX/01718330X/_            0
# 5862  8109  course-v1:UC_BerkeleyX+CS169_1x_1+2016_2017            0
# 6096  5882             course-v1:rongxin+cq01001+201603            0
# 6144   253                       FUDAN/FUDAN004/2014_T2            0
# 6180    82                        TsinghuaX/70167012X/_            0
#
#       category start_date   end_date  duration
# 0          NaN 2016-11-16 2016-12-31        45
# 1          NaN 2016-09-01 2017-02-28       180
# 3          NaN 2017-03-01 2017-07-01       122
# 4          NaN 2015-01-01 2015-09-10       252
# 5          NaN 2015-01-01 2018-09-17      1355
# ...        ...        ...        ...       ...
# 5741  computer 2015-01-01 2015-08-21       232
# 5862       NaN 2015-01-01 2015-08-21       232
# 6096       NaN 2017-01-01 2017-08-21       232
# 6144       NaN 2015-01-01 2015-08-21       232
# 6180       art 2015-01-01 2015-08-21       232
#
# [6410 rows x 7 columns]

# %% [markdown]
# ##3. Điền khuyết cho cột 'Category'

# %% [markdown]
# Lấy ra các dòng có dữ liệu ở cột 'category'

# %%
valid_rows = course_date[course_date['category'].notnull()]
valid_rows.info()
valid_rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1454 entries, 17 to 6180
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1454 non-null   object
#  1   course_id    1454 non-null   object
#  2   course_type  1454 non-null   int64
#  3   category     1454 non-null   object
#  4   start_date   1454 non-null   datetime64[ns]
#  5   end_date     1454 non-null   datetime64[ns]
#  6   duration     1454 non-null   int64
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 90.9+ KB
#          id                               course_id  course_type  \
# 17      577             TsinghuaX/70150023X/2015_T1            0
# 38     5735            course-v1:NJU+010101+2016_T1            0
# 41    11612          course-v1:DYU+dyuglbbx+2017_T2            0
# 45     9290  course-v1:TsinghuaX+00690302_2+2017_T2            0
# 59     2070   course-v1:TsinghuaX+00510663X+2015_T2            0
# ...     ...                                     ...          ...
# 5432    181         UC_BerkeleyX/CS169_1x_1/2014_T1            0
# 5452     79               TsinghuaX/10421084X/_B_1_            0
# 5722    195        TsinghuaX/60240013_2014X/2014_T2            0
# 5741     69                     PekingX/01718330X/_            0
# 6180     82                   TsinghuaX/70167012X/_            0
#
#             category start_date   end_date  duration
# 17       engineering 2015-03-02 2015-07-05       125
# 38    social science 2016-03-28 2017-02-15       324
# 41         economics 2015-01-01 2017-12-25      1089
# 45        literature 2017-04-03 2017-05-31        58
# 59          business 2015-10-12 2016-01-16        96
# ...              ...        ...        ...       ...
# 5432        computer 2015-01-01 2015-08-21       232
# 5452            math 2015-01-01 2015-08-21       232
# 5722            math 2015-01-01 2015-08-21       232
# 5741        computer 2015-01-01 2015-08-21       232
# 6180             art 2015-01-01 2015-08-21       232
#
# [1454 rows x 7 columns]

# %% [markdown]
# Lấy ra giá trị xuất hiện nhiều nhất ở cột 'category'

# %%
most_frequent_value = valid_rows['category'].mode()[0]
print(most_frequent_value)
# Out:
# computer

# %%
import matplotlib.pyplot as plt

valid_rows = course_date[course_date['category'].notnull()]
# Tạo dữ liệu
sizes = valid_rows['category'].value_counts()
labels = sizes.index


# Vẽ biểu đồ
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# Điền giá trị xuất hiện nhiều nhất cho các dòng có cột 'category' bị khuyết

# %%
invalid_rows = course_date[course_date['category'].isnull()]

# Tính số lượng hàng bị thiếu
num_missing = invalid_rows['category'].shape[0]

total = sum(sizes)
p = [size / total for size in sizes]

# Fill dữ liệu bị thiếu theo tỉ lệ
values = np.random.choice(labels, size=num_missing, p = p)
invalid_rows.loc[:,'category'] = values
invalid_rows.info()
invalid_rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4956 entries, 0 to 6144
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4956 non-null   object
#  1   course_id    4956 non-null   object
#  2   course_type  4956 non-null   int64
#  3   category     4956 non-null   object
#  4   start_date   4956 non-null   datetime64[ns]
#  5   end_date     4956 non-null   datetime64[ns]
#  6   duration     4956 non-null   int64
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 309.8+ KB
#         id                                    course_id  course_type  \
# 0     6561        course-v1:CPVS+CPVS-HDLSC001+20160901            0
# 1     5557                 course-v1:SCUT+144282+201709            0
# 3     8320                  course-v1:nuist+001+2016-T1            0
# 4      231                   FUDAN/CFD004/2014.9-2015.1            0
# 5     7645                 course-v1:ANUx+EBM05x+3T2017            0
# ...    ...                                          ...          ...
# 5516  5600    course-v1:VPC_TsinghuaX+30230931X+2016_T1            0
# 5622  7734               course-v1:DelftX+BMI.1x+3T2016            0
# 5862  8109  course-v1:UC_BerkeleyX+CS169_1x_1+2016_2017            0
# 6096  5882             course-v1:rongxin+cq01001+201603            0
# 6144   253                       FUDAN/FUDAN004/2014_T2            0
#
#             category start_date   end_date  duration
# 0          education 2016-11-16 2016-12-31        45
# 1                art 2016-09-01 2017-02-28       180
# 3          economics 2017-03-01 2017-07-01       122
# 4           computer 2015-01-01 2015-09-10       252
# 5        environment 2015-01-01 2018-09-17      1355
# ...              ...        ...        ...       ...
# 5516  social science 2015-01-01 2015-08-21       232
# 5622        computer 2016-12-13 2017-08-02       232
# 5862        computer 2015-01-01 2015-08-21       232
# 6096       economics 2017-01-01 2017-08-21       232
# 6144        medicine 2015-01-01 2015-08-21       232
#
# [4956 rows x 7 columns]

# %% [markdown]
# Tổng hợp lại vào course_date

# %%
course_date = pd.concat([valid_rows, invalid_rows])
course_date.info()
course_date
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6410 entries, 17 to 6144
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           6410 non-null   object
#  1   course_id    6410 non-null   object
#  2   course_type  6410 non-null   int64
#  3   category     6410 non-null   object
#  4   start_date   6410 non-null   datetime64[ns]
#  5   end_date     6410 non-null   datetime64[ns]
#  6   duration     6410 non-null   int64
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 400.6+ KB
#          id                                    course_id  course_type  \
# 17      577                  TsinghuaX/70150023X/2015_T1            0
# 38     5735                 course-v1:NJU+010101+2016_T1            0
# 41    11612               course-v1:DYU+dyuglbbx+2017_T2            0
# 45     9290       course-v1:TsinghuaX+00690302_2+2017_T2            0
# 59     2070        course-v1:TsinghuaX+00510663X+2015_T2            0
# ...     ...                                          ...          ...
# 5516   5600    course-v1:VPC_TsinghuaX+30230931X+2016_T1            0
# 5622   7734               course-v1:DelftX+BMI.1x+3T2016            0
# 5862   8109  course-v1:UC_BerkeleyX+CS169_1x_1+2016_2017            0
# 6096   5882             course-v1:rongxin+cq01001+201603            0
# 6144    253                       FUDAN/FUDAN004/2014_T2            0
#
#             category start_date   end_date  duration
# 17       engineering 2015-03-02 2015-07-05       125
# 38    social science 2016-03-28 2017-02-15       324
# 41         economics 2015-01-01 2017-12-25      1089
# 45        literature 2017-04-03 2017-05-31        58
# 59          business 2015-10-12 2016-01-16        96
# ...              ...        ...        ...       ...
# 5516  social science 2015-01-01 2015-08-21       232
# 5622        computer 2016-12-13 2017-08-02       232
# 5862        computer 2015-01-01 2015-08-21       232
# 6096       economics 2017-01-01 2017-08-21       232
# 6144        medicine 2015-01-01 2015-08-21       232
#
# [6410 rows x 7 columns]

# %% [markdown]
# ##4. Tạo kiểu dữ liệu timestamp

# %%
course_date['start_tsp'] = course_date['start_date'].astype('int64') // 10**9
course_date['end_tsp'] = course_date['end_date'].astype('int64') // 10**9
print(course_date)
# Out:
#          id                                    course_id  course_type  \
# 17      577                  TsinghuaX/70150023X/2015_T1            0
# 38     5735                 course-v1:NJU+010101+2016_T1            0
# 41    11612               course-v1:DYU+dyuglbbx+2017_T2            0
# 45     9290       course-v1:TsinghuaX+00690302_2+2017_T2            0
# 59     2070        course-v1:TsinghuaX+00510663X+2015_T2            0
# ...     ...                                          ...          ...
# 5516   5600    course-v1:VPC_TsinghuaX+30230931X+2016_T1            0
# 5622   7734               course-v1:DelftX+BMI.1x+3T2016            0
# 5862   8109  course-v1:UC_BerkeleyX+CS169_1x_1+2016_2017            0
# 6096   5882             course-v1:rongxin+cq01001+201603            0
# 6144    253                       FUDAN/FUDAN004/2014_T2            0
#
#             category start_date   end_date  duration   start_tsp     end_tsp
# 17       engineering 2015-03-02 2015-07-05       125  1425254400  1436054400
# 38    social science 2016-03-28 2017-02-15       324  1459123200  1487116800
# 41         economics 2015-01-01 2017-12-25      1089  1420070400  1514160000
# 45        literature 2017-04-03 2017-05-31        58  1491177600  1496188800
# 59          business 2015-10-12 2016-01-16        96  1444608000  1452902400
# ...              ...        ...        ...       ...         ...         ...
# 5516  social science 2015-01-01 2015-08-21       232  1420070400  1440115200
# 5622        computer 2016-12-13 2017-08-02       232  1481587200  1501632000
# 5862        computer 2015-01-01 2015-08-21       232  1420070400  1440115200
# 6096       economics 2017-01-01 2017-08-21       232  1483228800  1503273600
# 6144        medicine 2015-01-01 2015-08-21       232  1420070400  1440115200
#
# [6410 rows x 9 columns]

# %% [markdown]
# ##5. Lưu data

# %%
course_date.to_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/data_sau_xử_lý/course_info_processed.csv')

# %% [markdown]
# #user_info

# %%
print(user_info);
# Out:
#           user_id gender   education   birth
# 0             631   male        High  1997.0
# 1            2631   male  Bachelor's  1990.0
# 2            4231   male   Associate  1991.0
# 3            6031   male  Bachelor's  1988.0
# 4            7831    NaN         NaN     NaN
# ...           ...    ...         ...     ...
# 9627143  10435606    NaN         NaN     NaN
# 9627144  10437206    NaN         NaN     NaN
# 9627145  10438806    NaN         NaN     NaN
# 9627146  10440406    NaN         NaN     NaN
# 9627147  10442006    NaN         NaN     NaN
#
# [9627148 rows x 4 columns]

# %% [markdown]
# ## Cột gender

# %%
valid_rows = user_info[user_info['gender'].notnull()]
gender_map = {'male': 0,'female': 1}
valid_rows.loc[:,'gender'] = valid_rows['gender'].map(gender_map)
valid_rows.loc[:,'gender']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 5          0
#           ..
# 9626861    0
# 9626862    1
# 9626899    0
# 9626960    1
# 9627087    0
# Name: gender, Length: 1206352, dtype: object

# %%
invalid_rows = user_info[user_info['gender'].isnull()]

# Tính số lượng hàng bị thiếu
num_missing = invalid_rows.shape[0]

# Fill dữ liệu bị thiếu theo tỉ lệ 50/50
values = np.random.choice([0,1], size=num_missing)
invalid_rows.loc[:,'gender'] = values
invalid_rows
# Out:
#           user_id gender education  birth
# 4            7831      0       NaN    NaN
# 7           13631      1       NaN    NaN
# 20          46431      0       NaN    NaN
# 21          48231      1       NaN    NaN
# 27          64031      0       NaN    NaN
# ...           ...    ...       ...    ...
# 9627143  10435606      1       NaN    NaN
# 9627144  10437206      1       NaN    NaN
# 9627145  10438806      1       NaN    NaN
# 9627146  10440406      1       NaN    NaN
# 9627147  10442006      0       NaN    NaN
#
# [8420796 rows x 4 columns]

# %%
user_info = pd.concat([valid_rows, invalid_rows], axis=0)
user_info
# Out:
#           user_id gender   education   birth
# 0             631      0        High  1997.0
# 1            2631      0  Bachelor's  1990.0
# 2            4231      0   Associate  1991.0
# 3            6031      0  Bachelor's  1988.0
# 5            9631      0  Bachelor's  1992.0
# ...           ...    ...         ...     ...
# 9627143  10435606      1         NaN     NaN
# 9627144  10437206      1         NaN     NaN
# 9627145  10438806      1         NaN     NaN
# 9627146  10440406      1         NaN     NaN
# 9627147  10442006      0         NaN     NaN
#
# [9627148 rows x 4 columns]

# %% [markdown]
# ## Cột education

# %%
import matplotlib.pyplot as plt

valid_rows = user_info[user_info['education'].notnull()]
# Tạo dữ liệu
sizes = valid_rows['education'].value_counts()
labels = sizes.index


# Vẽ biểu đồ
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
invalid_rows = user_info[user_info['education'].isnull()]

# Tính số lượng hàng bị thiếu
num_missing = invalid_rows['education'].shape[0]

total = sum(sizes)
p = [size / total for size in sizes]

# Fill dữ liệu bị thiếu theo tỉ lệ
values = np.random.choice(labels, size=num_missing, p = p)
invalid_rows.loc[:,'education'] = values
invalid_rows
# Out:
#           user_id gender   education   birth
# 65         137231      0        High  1996.0
# 71         149031      0   Associate  1996.0
# 78         161231      0  Bachelor's  1998.0
# 88         179231      0  Bachelor's  1994.0
# 107        218831      1   Associate  1994.0
# ...           ...    ...         ...     ...
# 9627143  10435606      1  Bachelor's     NaN
# 9627144  10437206      1        High     NaN
# 9627145  10438806      1    Master's     NaN
# 9627146  10440406      1  Bachelor's     NaN
# 9627147  10442006      0   Associate     NaN
#
# [9298955 rows x 4 columns]

# %%
user_info = pd.concat([valid_rows, invalid_rows], axis=0)
user_info
# Out:
#           user_id gender   education   birth
# 0             631      0        High  1997.0
# 1            2631      0  Bachelor's  1990.0
# 2            4231      0   Associate  1991.0
# 3            6031      0  Bachelor's  1988.0
# 5            9631      0  Bachelor's  1992.0
# ...           ...    ...         ...     ...
# 9627143  10435606      1  Bachelor's     NaN
# 9627144  10437206      1        High     NaN
# 9627145  10438806      1    Master's     NaN
# 9627146  10440406      1  Bachelor's     NaN
# 9627147  10442006      0   Associate     NaN
#
# [9627148 rows x 4 columns]

# %% [markdown]
# ## Cột birth

# %%
user_info['birth'].describe()
# Out:
# count    481422.000000
# mean       1990.901448
# std          10.714057
# min         996.000000
# 25%        1989.000000
# 50%        1993.000000
# 75%        1995.000000
# max        7381.000000
# Name: birth, dtype: float64

# %%
not_null_rows = user_info[user_info['birth'].notnull()]

valid_rows = not_null_rows[(not_null_rows['birth'] > 1920) & (not_null_rows['birth'] < 2015)]

invalid_rows = not_null_rows[(not_null_rows['birth'] <= 1920) | (not_null_rows['birth'] >= 2015)]
invalid_rows.loc[:,'birth'] = np.nan

invalid_rows = pd.concat([invalid_rows, user_info[user_info['birth'].isnull()]])

_= pd.concat([invalid_rows, valid_rows], axis=0)
_['birth'] = _['birth'].bfill()
user_info = _
user_info
# Out:
#           user_id gender   education   birth
# 72298      280849      1  Bachelor's  1997.0
# 202358    6776280      1        High  1997.0
# 208379    6775883      1  Bachelor's  1997.0
# 240417   10125494      1    Master's  1997.0
# 278448    3039301      0        High  1997.0
# ...           ...    ...         ...     ...
# 9548961     79056      0   Doctorate  2014.0
# 9579048    101553      1   Associate  1991.0
# 9585223    434554      0  Bachelor's  1989.0
# 9603149    168003      0   Associate  2014.0
# 9615301    409605      1  Bachelor's  1995.0
#
# [9627148 rows x 4 columns]

# %% [markdown]
# ## Lưu data

# %%
user_info.to_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/data_sau_xử_lý/user_info_processed.csv')

# %% [markdown]
# #train_log

# %%
train_log.info()
train_log
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29165540 entries, 0 to 29165539
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   enroll_id   int64
#  1   username    int64
#  2   course_id   object
#  3   session_id  object
#  4   action      object
#  5   object      object
#  6   time        object
# dtypes: int64(2), object(5)
# memory usage: 1.5+ GB
#           enroll_id  username                              course_id  \
# 0               772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 1               772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 2               773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 3               773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 4               773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# ...             ...       ...                                    ...
# 29165535     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165536     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165537     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165538     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165539     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
#
#                                 session_id            action  \
# 0         d8a9b787fa69063c34c73b9c29190b1c       click_about
# 1         d8a9b787fa69063c34c73b9c29190b1c        click_info
# 2         2f02b86eb3ea2cbf0be11385a8dc62e5       pause_video
# 3         2f02b86eb3ea2cbf0be11385a8dc62e5        load_video
# 4         2f02b86eb3ea2cbf0be11385a8dc62e5        play_video
# ...                                    ...               ...
# 29165535  dff9476c7f05f26a69a06506fe471668  click_courseware
# 29165536  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165537  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165538  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165539  d94bf93252b8936bef09f6e46c24d50d       click_about
#
#                                     object                 time
# 0                                      NaN  2015-09-27T15:42:59
# 1                                      NaN  2015-09-27T15:43:12
# 2         3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:37:42
# 3         3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:33:27
# 4         3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:33:30
# ...                                    ...                  ...
# 29165535                               NaN  2016-04-01T21:04:38
# 29165536  556186425e7448e189918bafcb2ff30b  2016-04-01T21:04:38
# 29165537  1757e4fd85994ba9a2350780f96da89e  2016-04-01T21:04:38
# 29165538  686d5efcd27845379b4b90e41ece181d  2016-04-01T21:04:38
# 29165539                               NaN  2016-03-02T20:21:55
#
# [29165540 rows x 7 columns]

# %%
train_date = train_log.copy()
train_date['time'] = pd.to_datetime(train_date['time']).dt.normalize()
train_date.info()
train_date
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29165540 entries, 0 to 29165539
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   enroll_id   int64
#  1   username    int64
#  2   course_id   object
#  3   session_id  object
#  4   action      object
#  5   object      object
#  6   time        datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 1.5+ GB
#           enroll_id  username                              course_id  \
# 0               772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 1               772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 2               773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 3               773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 4               773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# ...             ...       ...                                    ...
# 29165535     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165536     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165537     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165538     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165539     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
#
#                                 session_id            action  \
# 0         d8a9b787fa69063c34c73b9c29190b1c       click_about
# 1         d8a9b787fa69063c34c73b9c29190b1c        click_info
# 2         2f02b86eb3ea2cbf0be11385a8dc62e5       pause_video
# 3         2f02b86eb3ea2cbf0be11385a8dc62e5        load_video
# 4         2f02b86eb3ea2cbf0be11385a8dc62e5        play_video
# ...                                    ...               ...
# 29165535  dff9476c7f05f26a69a06506fe471668  click_courseware
# 29165536  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165537  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165538  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165539  d94bf93252b8936bef09f6e46c24d50d       click_about
#
#                                     object       time
# 0                                      NaN 2015-09-27
# 1                                      NaN 2015-09-27
# 2         3dac5590435e43b3a65a9ae7426c16db 2015-10-19
# 3         3dac5590435e43b3a65a9ae7426c16db 2015-10-19
# 4         3dac5590435e43b3a65a9ae7426c16db 2015-10-19
# ...                                    ...        ...
# 29165535                               NaN 2016-04-01
# 29165536  556186425e7448e189918bafcb2ff30b 2016-04-01
# 29165537  1757e4fd85994ba9a2350780f96da89e 2016-04-01
# 29165538  686d5efcd27845379b4b90e41ece181d 2016-04-01
# 29165539                               NaN 2016-03-02
#
# [29165540 rows x 7 columns]

# %%
train_date.to_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/data_sau_xử_lý/train_log_processed.csv')

# %% [markdown]
# #test_log

# %%
test_log.info()
test_log
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12944862 entries, 0 to 12944861
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   enroll_id   int64
#  1   username    int64
#  2   course_id   object
#  3   session_id  object
#  4   action      object
#  5   object      object
#  6   time        object
# dtypes: int64(2), object(5)
# memory usage: 691.3+ MB
#           enroll_id  username                              course_id  \
# 0               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 1               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 2               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 3               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 4               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# ...             ...       ...                                    ...
# 12944857     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944858     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944859     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944860     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944861     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
#
#                                 session_id                   action  \
# 0         5f421f644193c2d48c84df42aaf7e48b               load_video
# 1         5f421f644193c2d48c84df42aaf7e48b               load_video
# 2         5f421f644193c2d48c84df42aaf7e48b               play_video
# 3         5f421f644193c2d48c84df42aaf7e48b              pause_video
# 4         5f421f644193c2d48c84df42aaf7e48b               stop_video
# ...                                    ...                      ...
# 12944857  b12bc83e13cd943cf61bf78f09c72158  problem_check_incorrect
# 12944858  b12bc83e13cd943cf61bf78f09c72158  problem_check_incorrect
# 12944859  b12bc83e13cd943cf61bf78f09c72158    problem_check_correct
# 12944860  7eca0904ae14dc8af809c0362632dd8e         click_courseware
# 12944861  b12bc83e13cd943cf61bf78f09c72158              problem_get
#
#                                     object                 time
# 0         3dac5590435e43b3a65a9ae7426c16db  2015-10-15T22:14:11
# 1         3169d758ee2d4262b07f0113df743c42  2015-10-15T22:43:35
# 2         3169d758ee2d4262b07f0113df743c42  2015-10-15T22:43:40
# 3         3169d758ee2d4262b07f0113df743c42  2015-10-15T22:55:38
# 4         3169d758ee2d4262b07f0113df743c42  2015-10-15T22:55:38
# ...                                    ...                  ...
# 12944857  31aa97345c46473badab334379f995d8  2016-03-19T21:37:15
# 12944858  31aa97345c46473badab334379f995d8  2016-03-19T21:37:22
# 12944859  31aa97345c46473badab334379f995d8  2016-03-19T21:37:37
# 12944860                               NaN  2016-03-19T19:24:44
# 12944861  a028651adbdc4bc0b53191117f874fbc  2016-03-19T21:38:34
#
# [12944862 rows x 7 columns]

# %%
test_date = test_log.copy()
test_date['time'] = pd.to_datetime(test_date['time']).dt.normalize()
test_date.info()
test_date
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12944862 entries, 0 to 12944861
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   enroll_id   int64
#  1   username    int64
#  2   course_id   object
#  3   session_id  object
#  4   action      object
#  5   object      object
#  6   time        datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 691.3+ MB
#           enroll_id  username                              course_id  \
# 0               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 1               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 2               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 3               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# 4               775   1520977  course-v1:TsinghuaX+70800232X+2015_T2
# ...             ...       ...                                    ...
# 12944857     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944858     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944859     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944860     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944861     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
#
#                                 session_id                   action  \
# 0         5f421f644193c2d48c84df42aaf7e48b               load_video
# 1         5f421f644193c2d48c84df42aaf7e48b               load_video
# 2         5f421f644193c2d48c84df42aaf7e48b               play_video
# 3         5f421f644193c2d48c84df42aaf7e48b              pause_video
# 4         5f421f644193c2d48c84df42aaf7e48b               stop_video
# ...                                    ...                      ...
# 12944857  b12bc83e13cd943cf61bf78f09c72158  problem_check_incorrect
# 12944858  b12bc83e13cd943cf61bf78f09c72158  problem_check_incorrect
# 12944859  b12bc83e13cd943cf61bf78f09c72158    problem_check_correct
# 12944860  7eca0904ae14dc8af809c0362632dd8e         click_courseware
# 12944861  b12bc83e13cd943cf61bf78f09c72158              problem_get
#
#                                     object       time
# 0         3dac5590435e43b3a65a9ae7426c16db 2015-10-15
# 1         3169d758ee2d4262b07f0113df743c42 2015-10-15
# 2         3169d758ee2d4262b07f0113df743c42 2015-10-15
# 3         3169d758ee2d4262b07f0113df743c42 2015-10-15
# 4         3169d758ee2d4262b07f0113df743c42 2015-10-15
# ...                                    ...        ...
# 12944857  31aa97345c46473badab334379f995d8 2016-03-19
# 12944858  31aa97345c46473badab334379f995d8 2016-03-19
# 12944859  31aa97345c46473badab334379f995d8 2016-03-19
# 12944860                               NaN 2016-03-19
# 12944861  a028651adbdc4bc0b53191117f874fbc 2016-03-19
#
# [12944862 rows x 7 columns]

# %%
test_date.to_csv('/content/drive/MyDrive/Nhóm 11/Đồ án môn học/Technology/data_sau_xử_lý/test_log_processed.csv')

# %%
test_date.isnull().sum()
# Out:
# enroll_id           0
# username            0
# course_id           0
# session_id          0
# action              0
# object        3314724
# time                0
# dtype: int64
